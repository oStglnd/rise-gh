# %% [markdown]
# # Short-term Temperature Model Test

# %% [markdown]
# ## Import dependencies and data

# %%
# import dependencies
import os
import json
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %%
# define relevant paths
home_path = os.path.dirname(os.getcwd())
data_path = home_path + '\\data\\'
plot_path = home_path + '\\plotting\\plots\\'
save_path = home_path + '\\model\\saved\\'

# %%
# get merged data
data = pd.read_csv(
    data_path + 'data_merged.csv',
    header=[0, 1],
    index_col=[0, 1, 2, 3, 4]
)

# convert index.date col to datetime
#data.index = pd.to_datetime(data.index.values)
data.loc[:, ('time', 'date')] = pd.to_datetime(data.time.date)

# %%
# define X vars
x_vars = [
    ('flow', 'TA01_GP101'),
    ('flow', 'FF01_GP101'),
    ('temperatures', 'DC_GT401_GM401'),
    ('temperatures', 'TA01_GT10X_GM10X'),
    ('temperatures', 'DC_GT301_damped'),
    ('temperatures', 'DC_GT301_outdoor'),
    ('setpoints', 'TA01_GT10X_GM10X'),
    ('sun', 'gsi'),
    ('sun', 'vol'),
    ('time', 'mod'),
    ('time', 'doy')
]

# filter columns to keep only x_vars
data = data[x_vars].copy()

# %% [markdown]
# ## Describe Df

# %%
# print number of NAs
print('Number of NAs\n')
print(data.isna().sum())
print('\n\n')
# Out:
# Number of NAs
#
# category      sensor_ID
# flow          TA01_GP101          13
#               FF01_GP101          12
# temperatures  DC_GT401_GM401      13
#               TA01_GT10X_GM10X    14
#               DC_GT301_damped     11
#               DC_GT301_outdoor    12
# setpoints     TA01_GT10X_GM10X    14
# sun           gsi                  1
#               vol                  1
# time          mod                  1
#               doy                  1
# dtype: int64

# %%
# remove single NANs
data = data[data.notnull()]

# %%
# describe cols
data.describe().transpose()
# Out:
#                                   count         mean         std  \
# category     sensor_ID
# flow         TA01_GP101        256309.0  2350.252129  606.494906
#              FF01_GP101        256310.0  2239.872041  571.442393
# temperatures DC_GT401_GM401    256309.0    49.457799    3.449037
#              TA01_GT10X_GM10X  256308.0    20.744784    1.277301
#              DC_GT301_damped   256311.0    -5.075647    6.692192
#              DC_GT301_outdoor  256310.0    -5.044795    6.653590
# setpoints    TA01_GT10X_GM10X  256308.0    20.661810    0.752604
# sun          gsi               256321.0    29.612166   73.867695
#              vol               256321.0   341.110775  959.500068
# time         mod               256321.0     0.631388    0.306815
#              doy               256321.0     0.316652    0.202922
#
#                                         min          25%          50%  \
# category     sensor_ID
# flow         TA01_GP101        1.761400e+03  1860.000000  2059.000000
#              FF01_GP101        1.358800e+03  1788.900000  1957.100000
# temperatures DC_GT401_GM401    1.540000e+01    48.700000    50.200000
#              TA01_GT10X_GM10X  1.170000e+01    19.900000    20.300000
#              DC_GT301_damped  -2.160000e+01   -10.400000    -3.800000
#              DC_GT301_outdoor -2.090000e+01   -10.300000    -3.700000
# setpoints    TA01_GT10X_GM10X  2.000000e+01    20.000000    20.000000
# sun          gsi               0.000000e+00     0.000000     0.003813
#              vol               0.000000e+00     0.000000     0.000000
# time         mod               0.000000e+00     0.378649     0.697790
#              doy               1.224647e-16     0.128748     0.296713
#
#                                        75%          max
# category     sensor_ID
# flow         TA01_GP101        2738.400000  4206.600000
#              FF01_GP101        2600.800000  4043.600000
# temperatures DC_GT401_GM401      51.200000    56.200000
#              TA01_GT10X_GM10X    21.500000    29.800000
#              DC_GT301_damped      0.100000     9.300000
#              DC_GT301_outdoor     0.300000     8.400000
# setpoints    TA01_GT10X_GM10X    21.500000    22.100000
# sun          gsi                 10.346306   491.320000
#              vol                  0.253222  3600.000000
# time         mod                  0.917060     1.000000
#              doy                  0.501242     0.668064

# %%
# import matplotlib.dates as mdates

# fig, ax = plt.subplots()

# #ax.plot(data.temperatures.TA01_GT10X_GM10X.values[-150000:-1])
# ax.plot(data.time.date.values[-100000:-1], data.flow.TA01_GP101.values[-100000:-1])

# myFmt = mdates.DateFormatter('%m-%d')
# ax.xaxis.set_major_formatter(myFmt)
# plt.show

# %%
data.time
# Out:
# sensor_ID                          mod       doy
# month day hour minute second
# 12    12  23   0      0       0.130526  0.162807
#                       30      0.130526  0.162807
#                1      0       0.128363  0.162807
#                       30      0.128363  0.162807
#                2      0       0.126199  0.162807
# ...                                ...       ...
# 3     26  21   58     0       0.263031  0.668064
#                       30      0.263031  0.668064
#                59     0       0.260926  0.668064
#                       30      0.260926  0.668064
#           22   0      0       0.258819  0.668064
#
# [260882 rows x 2 columns]

# %% [markdown]
# ## Process / transform variables

# %%
# remove erroneous setpoints data
data = data[data.setpoints.TA01_GT10X_GM10X != 0.0]

# # set temp to adjusted for setpoint
# data[('temperatures', 'TA01_GT10X_GM10X')] = data.temperatures.TA01_GT10X_GM10X \
#                                                 - (data.setpoints.TA01_GT10X_GM10X - 20.0)

# ## Use temperature Diff. w.r.t. setpoint
# #data[('temperatures', 'TA01_GT10X_GM10X_diff')] = \
# #    data[('temperatures', 'TA01_GT10X_GM10X')] - data[('setpoints', 'TA01_GT10X_GM10X_default')]

# Transform setpoints variable to instead account for difference w.r.t 20 deg C
data[('temperatures', 'setpoint_diff')] = data.setpoints.TA01_GT10X_GM10X - 20.0

# %%
# remove "OUTLIERS" from DC-TEMP
# data[('temperatures', 'DC_GT401_GM401_roll')] = data.temperatures.DC_GT401_GM401.rolling(window=240, center=False).mean()
data[('temperatures', 'DC_GT401_GM401_roll')] = data.temperatures.DC_GT401_GM401.rolling(window=240, center=False).mean()
data[('temperatures', 'DC_diff')] = np.abs(data.temperatures.DC_GT401_GM401 - data.temperatures.DC_GT401_GM401_roll)
data.loc[data.temperatures.DC_diff > 2, ('temperatures', 'DC_GT401_GM401')] = data.temperatures.DC_GT401_GM401_roll

# %%
# remove "OUTLIERS" from DC-FLOW
data[('flow', 'TA01_GP101')] = data.flow.TA01_GP101.apply(lambda val: max(1800, val))

# %%
# perform FFT 
fourier = np.fft.rfft( data.temperatures.DC_GT401_GM401.values)

# get FREQS
spacing = 1 / 100 # i.e. 1/10th of cycle PER step, due to 5-min cycles.
#spacing = 1
freqs = np.fft.rfftfreq(
    n = len(data),
    d = spacing
)

# filter fourier series
threshold = 1
fourier[freqs > threshold] = 0
filtered = np.fft.irfft(fourier)

# put in data
data.loc[:, ('temperatures', 'DC_GT401_GM401_fft')] = data[('temperatures', 'DC_GT401_GM401')]
data[('temperatures', 'DC_GT401_GM401_fft')].iloc[1:] = filtered

# %% [markdown]
# ### Plot pairwise correlation matrix

# %%
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(12, 6))
sns.heatmap(corr, mask=mask, vmin=-1.0, vmax=1.0, annot=True)

plt.xticks(rotation=45)
plt.title('Pairwise correlation plot')
plt.show()

# delete correlation data
del corr

# %% [markdown]
# ## Preparing data

# %%
t_steps = 20  # 10 minute predictions
n_steps = 30  # 15 minute backwards look

train_frac = 0.8

# %% [markdown]
# ### Data selection and whitening

# %%
# # save temp mean & std

# temp_mean = data.temperatures.TA01_GT10X_GM10X.mean()
# temp_std = data.temperatures.TA01_GT10X_GM10X.std()

# %%
# # normalize all columns
# for col in data.columns:
#     data[col] = (data[col] - data[col].mean()) / data[col].std()

# %%
# Define model variables
model_vars = [
    ('flow', 'TA01_GP101'),
    ('flow', 'FF01_GP101'),
    ('temperatures', 'DC_GT401_GM401_fft'),
    ('temperatures', 'TA01_GT10X_GM10X'),
    ('temperatures', 'DC_GT301_damped'),
    ('temperatures', 'DC_GT301_outdoor'),
    ('temperatures', 'setpoint_diff'),
    ('sun', 'gsi'),
    ('sun', 'vol'),
    ('time', 'mod'),
    ('time', 'doy')
]

# filter data
data = data[model_vars]

# %%
# define target
# targets = data.pop(('temperatures', 'TA01_GT10X_GM10X')).shift(periods=-t_steps)  # 0-minute forward
targets = data[('temperatures', 'TA01_GT10X_GM10X')].copy().shift(periods=-t_steps)

# remove NaNs
targets = targets.iloc[:-t_steps]
data = data.iloc[:-t_steps]

# %% [markdown]
# ### Create sequences (REMAKE)

# %%
# def date_flagger(data, n_steps):
#     # get flagged dates
#     data['day'] = data.index.get_level_values(1).values
#     data['date_flag'] = data.day - data.day.shift(periods=n_steps) > 1

#     # get positions in data, w.r.t. n_step removed observations at start
#     flagged_idx = np.where(data.date_flag.values == 1)
#     flagged_idx = flagged_idx[0] - n_steps
    
#     del data['day'], data['date_flag']
    
#     return flagged_idx

# %%
# get all n_step-sequences from data series
sequences = np.stack([
    data.values[i:i+n_steps, :] for i in range(len(data) - n_steps)
]) 

# get flagged sequences
flags = date_flagger(data, n_steps)

# get mask f. flags
mask = [idx not in flags for idx in range(len(sequences))]
sequences = sequences[mask]

# get targets, delete mask
targets = targets.values[n_steps:][mask]

# %%
# delete data 
del data

# save sequential seqs, targets for testing
sequences, test_seqs  = sequences[:-8640], sequences[-8640:]
targets, test_targets = targets[:-8640], targets[-8640:]

# %% [markdown]
# ### Shuffle and split dataset

# %%
# get random indices
idxs = np.arange(len(targets))
np.random.shuffle(idxs)

# shuffle sequences and targets
sequences = np.squeeze(sequences[idxs])
targets = np.squeeze(targets[idxs])

# %%
# split data
train_n = int(len(targets) * train_frac)
#test_n = len(targets) - train_n

X_train, X_test = sequences[:train_n], sequences[train_n:]
Y_train, Y_test = targets[:train_n], targets[train_n:]

# %%
# delete vars
del sequences, targets

# %% [markdown]
# ## Define model

# %%
layerList = [
    layers.Input(shape=(
        X_train.shape[1],
        X_train.shape[2]
    )),
    layers.BatchNormalization(),
    layers.Conv1D(
        filters=64,
#         filters=128,
        kernel_size=7, 
        padding="same", 
        strides=2, 
        activation="relu"
    ),
    layers.BatchNormalization(),
    layers.Conv1D(
        filters=64,
#         filters=128,
        kernel_size=7, 
        padding="same", 
        strides=2, 
        activation="relu"
    ),
    layers.BatchNormalization(),
    layers.Conv1D(
        filters=64,
#         filters=128,
        kernel_size=7, 
        padding="same", 
        strides=2, 
        activation="relu"
    ),
    layers.Flatten(),
    layers.BatchNormalization(),
    layers.Dense(
        units=128,
#         activation=None,
        activation='relu',
        activity_regularizer='l2'
    ),
    layers.BatchNormalization(),
    layers.Dense(
        units=128,
#         activation=None,
        activation='relu',
        activity_regularizer='l2'
    ),
    layers.BatchNormalization(),
    layers.Dense(
        units=1,
        activation=None,
        activity_regularizer='l2'
    )
]

# %%
lr = 0.005
model = tf.keras.models.Sequential(layers=layerList, name='model')
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_12 (Bat  (None, 30, 11)           44
#  chNormalization)
#
#  conv1d_6 (Conv1D)           (None, 15, 64)            4992
#
#  batch_normalization_13 (Bat  (None, 15, 64)           256
#  chNormalization)
#
#  conv1d_7 (Conv1D)           (None, 8, 64)             28736
#
#  batch_normalization_14 (Bat  (None, 8, 64)            256
#  chNormalization)
#
#  conv1d_8 (Conv1D)           (None, 4, 64)             28736
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  batch_normalization_15 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  batch_normalization_16 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 114,605
# Trainable params: 113,303
# Non-trainable params: 1,302
# _________________________________________________________________

# %%
trainHist = model.fit(
    X_train,
    Y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min"),
        tf.keras.callbacks.LearningRateScheduler(lambda epoch: lr * (0.9 ** epoch))
    ],
)
# Out:
# Epoch 1/10
# 1164/1164 [==============================] - 23s 17ms/step - loss: 17.8653 - val_loss: 4.6429 - lr: 0.0050
# Epoch 2/10
# 1164/1164 [==============================] - 19s 16ms/step - loss: 4.6079 - val_loss: 4.4696 - lr: 0.0045
# Epoch 3/10
# 1164/1164 [==============================] - 21s 18ms/step - loss: 4.4675 - val_loss: 5.0050 - lr: 0.0041
# Epoch 4/10
# 1164/1164 [==============================] - 19s 16ms/step - loss: 4.4349 - val_loss: 13.2082 - lr: 0.0036
# Epoch 5/10
# 1164/1164 [==============================] - 20s 17ms/step - loss: 4.4202 - val_loss: 10.5036 - lr: 0.0033
# Epoch 6/10
# 1164/1164 [==============================] - 21s 18ms/step - loss: 4.4096 - val_loss: 4.4586 - lr: 0.0030
# Epoch 7/10
# 1164/1164 [==============================] - 26s 23ms/step - loss: 4.3956 - val_loss: 4.4170 - lr: 0.0027
# Epoch 8/10
# 1164/1164 [==============================] - 24s 21ms/step - loss: 4.3860 - val_loss: 4.4180 - lr: 0.0024
# Epoch 9/10
# 1164/1164 [==============================] - 23s 20ms/step - loss: 4.3673 - val_loss: 5.2176 - lr: 0.0022
# Epoch 10/10
# 1164/1164 [==============================] - 23s 20ms/step - loss: 4.3801 - val_loss: 4.5468 - lr: 0.0019

# %%
# model_name = 'temp_model_v6'
# model.save(save_path + model_name)

# %%
preds = model.predict(X_test)
vis_preds = model.predict(test_seqs)
# Out:
# 1455/1455 [==============================] - 6s 4ms/step
# 270/270 [==============================] - 1s 4ms/step

# %%
test_mae = np.abs(np.squeeze(preds) - Y_test) 
temp_diffs = test_mae# * temp_std

# %%
diff_df = pd.DataFrame(temp_diffs)

sns.histplot(
    data=diff_df,
    stat='count',
    binwidth=0.01,
    binrange=[0, 2.0],
    kde=False,
    palette='bright',
    legend=False
)

plt.title('Distribution of MAE for 10-minute forward predictions')
plt.xlim(0, 2.0)
plt.xlabel('Temperature error, $^\circ$C')

#plt.savefig(plot_path + 'temp_error_dist.png', bbox_inches='tight', dpi=200)
plt.show()

# %%
plt.plot(
    np.squeeze(test_targets),# * temp_std + temp_mean,
    c='b',
    alpha=0.6,
    linewidth=2.5,
    label='Real'
)

plt.plot(
    vis_preds,# * temp_std + temp_mean,
    c='r',
    alpha=0.8,
    linewidth=1.5,
    label='Predicted'
)

plt.ylabel('Temperature, $^\circ$C')
plt.xlabel('Steps, $t$')
plt.legend(loc='upper left')
plt.title('Temperature - 10-minute forward predictions')

plt.ylim(15, 30)
plt.xlim(0, len(vis_preds))

#plt.savefig(plot_path + 'temp_preds_10min.png', bbox_inches='tight', dpi=200)

plt.show()

# %%
fig, ax = plt.subplots(layout='constrained')
ax.plot(np.squeeze(test_targets)[-3000:], c='b')
ax.plot(vis_preds[-3000:], c='m')

# ax_sec = ax.twinx()

# ax_sec.plot(test_seqs[-8000:, 0, 0], c='r', linewidth=1.5, alpha=0.8)
# ax_sec.set_ylim(0, 5000)
# #plt.plot(test_seqs[-4000:, 0, 0])

plt.show()

# %%
np.corrcoef(test_targets, np.squeeze(vis_preds))
# Out:
# array([[1.        , 0.98175752],
#        [0.98175752, 1.        ]])

# %%
np.corrcoef(np.squeeze(preds), Y_test)
# Out:
# array([[ 1.       , -0.0089492],
#        [-0.0089492,  1.       ]])

# %%
plt.plot(preds[-100000:])
