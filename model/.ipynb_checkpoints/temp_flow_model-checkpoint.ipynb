# %% [markdown]
# # Temp/Flow Model Test

# %% [markdown]
# ## Import dependencies and data

# %%
# import dependencies
import os
import json
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
#import tensorflow as tf
#from tensorflow.keras import layers

# %%
# define relevant paths
home_path = os.path.dirname(os.getcwd())
data_path = home_path + '\\data\\'
plot_path = home_path + '\\plotting\\plots\\'

# %%
# get merged data
data = pd.read_csv(
    data_path + 'data_merged.csv',
    header=[0, 1],
    index_col=[0, 1, 2, 3]
)

# convert index.date col to datetime
data.index = data.index.set_levels(
    levels=pd.to_datetime(data.index.get_level_values(3).values),
    level=3
)

# %%
# Use temperature Diff. w.r.t. setpoint
data[('temperatures', 'TA01_GT10X_GM10X_diff')] = \
    data[('temperatures', 'TA01_GT10X_GM10X')] - data[('setpoints', 'TA01_GT10X_GM10X_default')]

# %%
# define X vars
x_vars = [
    ('state', 'DC_SP105_relative'),
    ('state', 'DC_SP107_relative'),
    ('state', 'DC_SP110_relative'),
    ('flow', 'TA01_SP102_relative'),
    ('flow', 'TA01_SP102_absolute'),
    ('flow', 'DC_SP105_relative'),
    ('flow', 'DC_SP105_absolute'),
    ('flow', 'DC_SP106_relative'),
    ('flow', 'DC_SP106_absolute'),
    ('flow', 'DC_SP107_relative'),
    ('flow', 'DC_SP107_absolute'),
    ('flow', 'DC_SP110_relative'),
    ('flow', 'DC_SP110_absolute'),
    ('flow', 'TA01_GP101_default'),
    ('pressure', 'TA01_GP101'),
    ('pressure', 'TA01_GP401'),
    ('pressure', 'DC_GP101'),
    ('temperatures', 'TA01_GT10X_GM10X'),
    ('temperatures', 'TA01_GT10X_GM10X_diff'),
    ('temperatures', 'DC_GT301_damped'),
    ('temperatures', 'DC_GT401_GM401')
]

mask = data.index.get_level_values(0) == 2
subset = data[mask][x_vars].copy()

# %% [markdown]
# ## Describe Df

# %%
subset.describe().transpose()
# Out:
#                                       count          mean           std   min  \
# category     sensor_ID
# state        DC_SP105_relative      54601.0     25.622826     34.378745   0.0
#              DC_SP107_relative      54601.0     63.960222     39.300492   0.0
#              DC_SP110_relative      54601.0     86.071294     24.781099   0.0
# flow         TA01_SP102_relative    54601.0     55.224207     60.796318   0.0
#              TA01_SP102_absolute    54601.0  14911.389645  21002.173365   0.0
#              DC_SP105_relative      54601.0     42.965977     49.989513   0.0
#              DC_SP105_absolute      54601.0  16834.811267  20726.202488   0.0
#              DC_SP106_relative      54601.0     80.662385     73.100564   0.0
#              DC_SP106_absolute      54601.0   5221.713632  10087.608470   0.0
#              DC_SP107_relative      54601.0      8.531879      7.082321   0.0
#              DC_SP107_absolute      54601.0   4054.103679   3365.186963   0.0
#              DC_SP110_relative      54601.0     13.102689      5.610214   0.0
#              DC_SP110_absolute      54601.0   6226.128917   2666.599884   0.0
#              TA01_GP101_default     54601.0   2152.202903    514.701527   0.0
# pressure     TA01_GP101             54601.0    327.883746    156.381477   0.9
#              TA01_GP401             54601.0    134.721575     34.715576   2.2
#              DC_GP101               54601.0      3.911558      0.595029  -0.3
# temperatures TA01_GT10X_GM10X       54601.0     20.423120      1.030055  14.6
#              TA01_GT10X_GM10X_diff  54601.0      0.045228      0.810989  -5.4
#              DC_GT301_damped        54601.0     -4.037725      6.749486 -21.6
#              DC_GT401_GM401         54601.0     48.824434      2.837791  24.9
#
#                                        25%     50%      75%      max
# category     sensor_ID
# state        DC_SP105_relative         0.0     0.0     50.2    100.0
#              DC_SP107_relative        24.6    94.1     94.2     94.4
#              DC_SP110_relative        96.1    96.1     96.1     96.3
# flow         TA01_SP102_relative       0.0    24.8    116.0    150.0
#              TA01_SP102_absolute       0.0  1970.0  30678.0  65534.0
#              DC_SP105_relative         0.0    12.2     84.2    150.0
#              DC_SP105_absolute         0.0  1011.0  34955.0  65534.0
#              DC_SP106_relative         0.0   144.6    150.0    150.0
#              DC_SP106_absolute         0.0  5744.0   5744.0  65520.0
#              DC_SP107_relative         0.0    12.4     14.5     37.7
#              DC_SP107_absolute         0.0  5911.0   6866.0  15120.0
#              DC_SP110_relative        13.2    14.9     16.2     34.3
#              DC_SP110_absolute      6282.0  7075.0   7702.0  17720.0
#              TA01_GP101_default     1858.0  1908.4   2404.4   4080.8
# pressure     TA01_GP101              231.2   243.7    386.9   1117.2
#              TA01_GP401              114.3   117.4    152.8    275.4
#              DC_GP101                  3.6     3.9      4.3     19.5
# temperatures TA01_GT10X_GM10X         19.9    20.1     21.1     25.9
#              TA01_GT10X_GM10X_diff    -0.2     0.0      0.2      5.4
#              DC_GT301_damped          -7.2    -3.1      0.6      8.4
#              DC_GT401_GM401           48.6    49.7     50.5     52.6

# %% [markdown]
# ### Plot pairwise correlation matrix

# %%
corr = subset.corr()

plt.figure(figsize=(12, 6))
#sns.heatmap(corr, vmin=-1.0, vmax=1.0, annot=True, cmap='Blues')

mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, vmin=-1.0, vmax=1.0, annot=True, cmap='Blues')

plt.xticks(rotation=45)
plt.title('Pairwise correlation plot')
plt.show()

# delete correlation data
del corr
