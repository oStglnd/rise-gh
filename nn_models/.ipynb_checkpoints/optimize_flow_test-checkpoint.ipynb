# %% [markdown]
# # Greenhouse Model

# %% [markdown]
# ## Import dependencies and data

# %%
# import dependencies

import time
import os
import pickle
import json
from collections import deque
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import clear_output

# %%
from data_funcs import k_fold_data_validation

# %% [markdown]
# ### Plot settings

# %%
plot_path = home_path + '\\nn_models\\plots\\'

# set plot defaults
plt.rcdefaults()

font = {
    'family' : 'arial',
    'weight' : 'normal',
    'size'   : 14
}

tit_font = {
    'family' : 'arial',
    'weight' : 'bold',
    'size'   : 16
}

suptit_font = {
    'family' : 'arial',
    'weight' : 'bold',
    'size'   : 18
}

plt.rc('font', **font)

# %% [markdown]
# ### Get data

# %%
# define relevant paths
home_path = os.path.dirname(os.getcwd())
data_path = home_path + '\\data\\'
results_path = home_path + '\\nn_models\\results\\'

# get merged data
data = pd.read_csv(
    data_path + 'data_processed.csv',
    header=[0, 1],
    index_col=[0, 1, 2, 3, 4]
)

# %%
# define data specs
k_frac = 0.05
m = 5
t_steps = 1
n_steps = 6

# Define cols to use
cols = [
    ('temperatures', 'TA01_GT10X_GM10X'),
    ('temperatures', 'TA01_GT401_GM401'),
    ('temperatures', 'DC_GT301_damped'),
    ('sun', 'gsi'),
    ('power', 'phase'),
#     ('time', 'minofday'),
#     ('state', 'TA01_output'),
#     ('state', 'TA02_output'),
    ('temperatures', 'TA01_GT401_GM401_scaled'),
    ('temperatures', 'DC_GT301_damped_scaled'),
]

# %% [markdown]
# ## Get data for all folds

# %%
# flow_results = {}

# %%
k_idx = 19
flow_results[k_idx] = {}

# %%
# get test data
_, test_tup, _, col_params = k_fold_data_validation(
    data=data.copy(), 
    k_idx=k_idx, 
    k_frac=k_frac, 
    m=m, 
    cols=cols, 
    t_steps=t_steps, 
    n_steps=n_steps,
    setpoint=True,
    shuffle=False
)

# extract test targets
(sequences_test, targets_test, temps_test, temps_t_test, sequences_masked, dates_test) = test_tup

# %%
# temp_mean, temp_std, _, _ = col_params[('temperatures', 'TA01_GT10X_GM10X')].values()
# temp_dc_mean, temp_dc_std, _, _ = col_params[('temperatures', 'TA01_GT401_GM401')].values()
# temp_out_mean, temp_out_std, _, _ = col_params[('temperatures', 'DC_GT301_damped')].values()

# ta01_mean, ta01_std, _, _ = col_params[('state', 'TA01_output')].values()
# ta02_mean, ta02_std, _, _ = col_params[('state', 'TA02_output')].values()

# %%
# ta01_actual = sequences_test[:n, -1, -2] * ta01_std + ta01_mean
# ta02_actual = sequences_test[:n, -1, -1] * ta02_std + ta02_mean

# %% [markdown]
# ### Get model

# %%
version = 26

# %%
model_name = 'rnn_v{}_k{}'.format(version, k_idx)
load_path = results_path + 'RNN\\' + model_name + '.pickle'

with open(load_path, 'rb') as fo:
    results = pickle.load(fo)

# %%
k1 = 6
k2 = 1
M = 32
seed = 1

model = recurrentNeuralNetwork(
    k1=k1,
    k2=k2,
    m=M,
    seed=seed
)

model.weights = results['weights']

# %% [markdown]
# ## Approximation of $\phi$

# %%
from scipy.interpolate import RegularGridInterpolator
from scipy.optimize import minimize

# %%
# def grid_estimation(seq, temp, k, col_params, model):
    
#     ta01_mean, ta01_std, _, _ = col_params[('state', 'TA01_output')].values()
#     ta02_mean, ta02_std, _, _ = col_params[('state', 'TA02_output')].values()
    
#     ta01 = (np.linspace(0, 100, k) - ta01_mean) / ta01_std
#     ta02 = (np.linspace(0, 100, k) - ta02_mean) / ta02_std
    
#     seqs = []
    
#     for i in range(k):
#         for j in range(k):
#             new_seq = seq.copy()
#             new_seq[-1, -2] = ta01[j]
#             new_seq[-1, -1] = ta02[i]
            
#             seqs.append(new_seq)
    
#     return seqs

# %%
def grid_estimation(seq, temp, k, col_params, model):
    
    ta01_min, ta01_max = 35, 75
    ta02_min, ta02_max = 0, 85
    
    ta01_mean, ta01_std, _, _ = col_params[('temperatures', 'TA01_GT401_GM401_scaled')].values()
    ta02_mean, ta02_std, _, _ = col_params[('temperatures', 'DC_GT301_damped_scaled')].values()
    
    temp_mean, temp_std, _, _ = col_params[('temperatures', 'TA01_GT10X_GM10X')].values()
    temp_dc_mean, temp_dc_std, _, _ = col_params[('temperatures', 'TA01_GT401_GM401')].values()
    temp_out_mean, temp_out_std, _, _ = col_params[('temperatures', 'DC_GT301_damped')].values()
    
    temp = temp * temp_std + temp_mean
    temp_dc = seq[-1, 0] * temp_dc_std + temp_dc_mean
    temp_out = seq[-1, 1] * temp_out_std + temp_out_mean
    
    ta01 = ((temp_dc - temp) * np.linspace(0, 100, k) / ta01_min - ta01_mean) / ta01_std
    ta02 = ((temp_out - temp) * np.linspace(0, 100, k) / ta01_min - ta02_mean) / ta02_std
    
#     ta01 = (np.linspace(0, 100, k) - ta01_mean) / ta01_std
#     ta02 = (np.linspace(0, 100, k) - ta02_mean) / ta02_std
    
    seqs = []
    
    for i in range(k):
        for j in range(k):
            new_seq = seq.copy()
            new_seq[-1, -2] = ta01[j]
            new_seq[-1, -1] = ta02[i]
            
            seqs.append(new_seq)
    
    return seqs

# %% [markdown]
# ### Flow optimization

# %%
k = 100
penalty = 0.01
alpha = 0.8
setpoint = (20 - temp_mean) / temp_std

# %%
ex_preds = []
ta01_flows = []
ta02_flows = []

seqs_masked = sequences_masked.copy()

ta01, ta02 = 0, 0
# phi = np.array([0, 0])
# temp = temps_t_test[:1]

for idx, (seq, temp, target) in enumerate(zip(seqs_masked, temps_t_test, targets_test)):
    # get all sequences and predictions
    seqs = grid_estimation(seq, temp, k, col_params, model)
    preds, _ = model.predict(np.stack(seqs), np.ones((k*k, 1)) * temp[0], train=False)

    # create k by k grid w. setpoint distances
    output_grid = np.abs(preds.reshape((k, k)) - target[0])#setpoint

    # interpolate and cast grid to [0, 100]x[0, 100]
    grid = RegularGridInterpolator(
            points=(np.linspace(0, 100, k), np.linspace(0, 100, k)),
            values=output_grid
    )
    
    grid = RegularGridInterpolator(points=(np.linspace(0, 100, k), np.linspace(0, 100, k)), values=output_grid.T)
    def obj(x):
        ta01_new, ta02_new = x
#         grid = RegularGridInterpolator(
#             points=(np.linspace(0, 100, k), np.linspace(0, 100, k)),
# #             values=output_grid.T + penalty * (1 - np.dot(phi, x) / (np.linalg.norm(phi)*np.linalg.norm(x)) + 1e-8)
#             values=output_grid.T + penalty * np.sqrt((ta01 - ta01_new)**2 + (ta02 - ta02_new)**2)
#         )
        value = grid([ta01_new, ta02_new]) + penalty * np.sqrt((ta01 - ta01_new)**2 + (ta02 - ta02_new)**2)#**2
        return value

    opt = minimize(
        fun=obj, 
        x0=[50, 50], 
        method='Nelder-Mead', 
        bounds=[(0, 99), (0, 99)],
        options={'disp': False}
    )

    ta01_new, ta02_new = opt.x 
#     phi = opt.x
    
    ta01 = alpha * ta01 + (1 - alpha) * ta01_new
    ta02 = alpha * ta02 + (1 - alpha) * ta02_new
    
    ta01_flows.append(ta01)
    ta02_flows.append(ta02)
    
    new_seq = seq.copy()
    new_seq[-1, -2] = (ta01 - ta01_mean) / ta01_std
    new_seq[-1, -1] = (ta02 - ta02_mean) / ta02_std
    
    temp_pred, _ = model.predict(new_seq[np.newaxis, :], temp[np.newaxis, :], train=False)
    ex_preds.append(temp_pred)

#     # adjust sequences!!!!
#     try:
#         for t in range(1, n_steps-t_steps):
#             seqs_masked[idx+t, n_steps-t_steps-t, -2] = (ta01 - ta01_mean) / ta01_std 
#             seqs_masked[idx+t, n_steps-t_steps-t, -1] = (ta02 - ta02_mean) / ta02_std
#     except IndexError:
#         break

# %%
# flow_results[k_idx]['base'] = [ta01_flows, ta02_flows, ex_preds]
flow_results[k_idx]['penalty'] = [ta01_flows, ta02_flows, ex_preds]

# %% [markdown]
# ## Plot difference in $\phi$

# %%
n = 2000

# %%
dates = pd.to_datetime(dates_test).strftime('%Y-%m-%d')[-n:]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_size_inches(18, 6)

ax1.plot(flow_results[12]['base'][0], color='darkgreen', label='Predicted')
ax1.plot(ta01_actual, color='darkorange', label='Actual')
ax1.set_xlim(0, n)
ax1.set_ylim(0, 100)
# ax1.set_xlabel('Steps, $t$ (5 min.)')
ax1.set_ylabel('%', rotation=0, labelpad=10)
ax1.legend(loc='upper right')
ax1.set_title('TA01, $\\alpha = 0.0$, $\\beta = 0.0$', **tit_font)
ax1.set_xticklabels(dates[::200], rotation=45)


ax2.plot(flow_results[12]['base'][1], color='forestgreen', label='Predicted')
ax2.plot(ta02_actual, color='darkorange', label='Actual')
ax2.set_xlim(0, n)
ax2.set_ylim(0, 100)
# ax2.set_xlabel('Steps, $t$ (5 min.)')
ax2.set_ylabel('%', rotation=0, labelpad=10)
ax2.legend(loc='upper right')
ax2.set_title('TA01, $\\alpha = 0.01$, $\\beta = 0.9$', **tit_font)
ax2.set_xticklabels(dates[::200], rotation=45)

# plt.savefig(plot_path + 'flow_comp_3.png', dpi=200, bbox_inches='tight')

plt.show()
# Out:
# C:\Users\Oskar\AppData\Local\Temp\ipykernel_21324\2587726094.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(dates[::200], rotation=45)
# C:\Users\Oskar\AppData\Local\Temp\ipykernel_21324\2587726094.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(dates[::200], rotation=45)

# %%
# fig, (ax1, ax2) = plt.subplots(1, 2)
# fig.set_size_inches(18, 6)

# ax1.plot(results[k_idx][0.011][0], color='darkgreen', label='Predicted')
# ax1.plot(ta01_actual, color='darkorange', label='Actual')
# ax1.set_xlim(0, n)
# ax1.set_ylim(0, 100)
# ax1.set_xlabel('Steps, $t$ (5 min.)')
# ax1.set_ylabel('%', rotation=0, labelpad=10)
# ax1.legend(loc='upper right')
# ax1.set_title('TA01 with $\\alpha = 0.01$', **tit_font)
# ax1.set_xticklabels(dates[::200])


# ax2.plot(results[k_idx][0.0][0], color='forestgreen', label='Predicted')
# ax2.plot(ta01_actual, color='darkorange', label='Actual')
# ax2.set_xlim(0, n)
# ax2.set_ylim(0, 100)
# ax2.set_xlabel('Steps, $t$ (5 min.)')
# ax2.set_ylabel('%', rotation=0, labelpad=10)
# ax2.legend(loc='upper right')
# ax2.set_title('TA01 with $\\alpha = 0.0$', **tit_font)

# plt.savefig(plot_path + 'flow_comp.png', dpi=200, bbox_inches='tight')
# Out:
# C:\Users\Oskar\AppData\Local\Temp\ipykernel_21324\1385941525.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(dates[::200])
